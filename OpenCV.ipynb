# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('Desktop/41_thumbnail.png')
#OpenCV and matplot lib are different in interpreting order
#matplot = RGB
#openCv = BGR

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#OpenCV doesn't provide the wrong warning provide while providing the image to opencv

# %%
img.shape
# Out:
# (1790, 3000, 3)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
#It basically means when we open any image from opencv2, it will show the color aspect
#In Blue, green, and red color while the actual color scheme should be RGB
#this we can aler via command cv2.cvtCOlor(image, cv2.COLOR_BGR2RGB)

# %%
img_gray = cv2.imread('Desktop/41_thumbnail.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap ='gray')

# %%
#Note, there is no third dimension
img_gray.shape
# Out:
# (1790, 3000)

# %%
fix_img.shape
# Out:
# (1790, 3000, 3)

# %%
#Cv2 has a function called which will take the input, and you can modify it
#It also takes opposite of X and Y, while numpy takes the reverse
new_img = cv2.resize(fix_img, (3200, 1800))

# %%
plt.imshow(new_img)

# %%
#Lets do the reduction with respect to ratio
#Image width and height 
width_r = 0.8
height_r = 0.2

# %%
img_modified = cv2.resize(new_img,(0,0),new_img, width_r, height_r)

# %%
img_modified.shape
# Out:
# (360, 2560, 3)

# %%
plt.imshow(img_modified)

# %%
alt_image = cv2.flip(new_img, -1)

# %%
plt.imshow(alt_image)

# %%
#How to save file
cv2.imwrite('Desktop/41_modified.jpg', new_img)
# Out:
# True
